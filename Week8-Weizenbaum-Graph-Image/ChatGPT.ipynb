# %% [markdown]
# # ChatGPT: Optimizing Language Models for Dialogue
#
# https://openai.com/blog/chatgpt/

# %% [markdown]
# ![ChatGPT_1.png](attachment:036cb725-c6de-4ea7-a903-136461a84320.png)

# %% [markdown]
# ![ChatGPT_2.png](attachment:0b1be676-7ba0-48ff-b7c0-5d11f313fa02.png)
